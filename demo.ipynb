# %%
# Create sub holding key.
"""
------------------------
Creating an API Factory:
------------------------

The snippet below loads LUSID and other packages needed for the snippet examples.

We also create an API factory for interacting with the LUSID's API methods.

"""

# Set up LUSID
import os
import pandas as pd
import json
import uuid
import pytz
from IPython.core.display import HTML
from datetime import datetime, timedelta, timezone
import pprint as pp

import logging
logging.basicConfig(level=logging.INFO)

# Import LUSID SDK
import lusid
import lusid.models as models

from lusid.utilities import ApiClientFactory
from lusidjam import RefreshingToken
from lusidtools.pandas_utils.lusid_pandas import lusid_response_to_data_frame
from lusidtools.jupyter_tools import StopExecution
from lusidtools.lpt.lpt import to_date

# Set pandas display options
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.options.display.float_format = "{:,.2f}".format

# Authenticate to SDK
# Run the Notebook in Jupyterhub for your LUSID domain and authenticate automatically
secrets_path = os.getenv("FBN_SECRETS_PATH")

# Run the Notebook locally using a secrets file (see https://support.lusid.com/knowledgebase/article/KA-01663)
if secrets_path is None:
    secrets_path = os.path.join(os.path.dirname(os.getcwd()), "secrets.json")

api_factory = ApiClientFactory(
    token=RefreshingToken(),
    api_secrets_filename=secrets_path,
    app_name="VSCode"
)

print('LUSID Environment Initialised')
print('API Version: ', api_factory.build(
    lusid.api.ApplicationMetadataApi).get_lusid_versions().build_version)

# Define a portfolio and parameters.
portfolio_code = "JC_UK"
portfolio_name = "Joe Cockings Demo Portfolio"
scope = "Demo2"

domain = "Portfolio"
sub_holding_key_code = "strategy"

portfolio_sub_holding_keys = [f"Transaction/{scope}/{sub_holding_key_code}"]

# Create a new sub-holding key via API.
property_definition_api = api_factory.build(lusid.api.PropertyDefinitionsApi)

# Attempt to create a SHK definition.
try:
    create_shk = property_definition_api.create_property_definition(
        create_property_definition_request = models.CreatePropertyDefinitionRequest(
            domain = "Transaction",
            scope = scope,
            code = "strategy",
            display_name = "Strategy",
            data_type_id = models.ResourceId(
                scope = "system",
                code = "string",
            ),
            life_time = "Perpetual",
            property_description = "Strategy of the trade",
        )
    )
    
    print(create_shk)

except lusid.ApiException as e:
    print(e)
    print(json.loads(e.body)["title"])


# Define instrument property for moodys rating.
inst_prop_rating_code = 'MoodyRating'

try:
    create_inst_prop = property_definition_api.create_property_definition(
        create_property_definition_request = models.CreatePropertyDefinitionRequest(
            domain = "Instrument",
            scope = scope,
            code = inst_prop_rating_code,
            display_name = "Moody's Rating",
            data_type_id = models.ResourceId(
                scope = "system",
                code = "number",
            ),
            life_time = "TimeVariant",
            property_description = "Moody's rating of the instrument",
        )
    )
    
    print(create_inst_prop)

except lusid.ApiException as e:
    print(e)
    print(json.loads(e.body)["title"])
# Out:
# LUSID Environment Initialised
# API Version:  0.6.13127.0
# {'code': 'strategy',
#  'collection_type': None,
#  'constraint_style': 'Property',
#  'data_type_id': {'code': 'string', 'scope': 'system'},
#  'derivation_formula': None,
#  'display_name': 'Strategy',
#  'domain': 'Transaction',
#  'href': None,
#  'key': 'Transaction/Demo2/strategy',
#  'life_time': 'Perpetual',
#  'links': [{'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/schemas/entities/PropertyDefinition',
#             'method': 'GET',
#             'relation': 'EntitySchema'},
#            {'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN49EQTFEAMS:0000003B',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'properties': {},
#  'property_definition_type': 'ValueProperty',
#  'property_description': 'Strategy of the trade',
#  'scope': 'Demo2',
#  'type': 'Label',
#  'unit_schema': 'NoUnits',
#  'value_required': False,
#  'value_type': 'String',
#  'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 7, 48, 914970, tzinfo=tzutc()),
#              'as_at_date': datetime.datetime(2024, 6, 11, 13, 7, 48, 914970, tzinfo=tzutc()),
#              'as_at_modified': datetime.datetime(2024, 6, 11, 13, 7, 48, 914970, tzinfo=tzutc()),
#              'as_at_version_number': 1,
#              'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#              'entity_unique_id': '65578035-5fd6-4b22-a2f8-b76c1139fbed',
#              'request_id_created': '0HN49EQTFEAMS:0000003B',
#              'request_id_modified': '0HN49EQTFEAMS:0000003B',
#              'staged_modification_id_modified': None,
#              'user_id_created': '00uv7uac52NTBxe1e2p7',
#              'user_id_modified': '00uv7uac52NTBxe1e2p7'}}
# {'code': 'MoodyRating',
#  'collection_type': None,
#  'constraint_style': 'Property',
#  'data_type_id': {'code': 'number', 'scope': 'system'},
#  'derivation_formula': None,
#  'display_name': "Moody's Rating",
#  'domain': 'Instrument',
#  'href': None,
#  'key': 'Instrument/Demo2/MoodyRating',
#  'life_time': 'TimeVariant',
#  'links': [{'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/schemas/entities/PropertyDefinition',
#             'method': 'GET',
#             'relation': 'EntitySchema'},
#            {'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN49EJ19VIC9:00000087',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'properties': {},
#  'property_definition_type': 'ValueProperty',
#  'property_description': "Moody's rating of the instrument",
#  'scope': 'Demo2',
#  'type': 'Metric',
#  'unit_schema': 'NoUnits',
#  'value_required': False,
#  'value_type': 'Decimal',
#  'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 7, 50, 188337, tzinfo=tzutc()),
#              'as_at_date': datetime.datetime(2024, 6, 11, 13, 7, 50, 188337, tzinfo=tzutc()),
#              'as_at_modified': datetime.datetime(2024, 6, 11, 13, 7, 50, 188337, tzinfo=tzutc()),
#              'as_at_version_number': 1,
#              'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#              'entity_unique_id': '9e3f54db-60f9-4dd7-ae57-43f63fcd3955',
#              'request_id_created': '0HN49EJ19VIC9:00000087',
#              'request_id_modified': '0HN49EJ19VIC9:00000087',
#              'staged_modification_id_modified': None,
#              'user_id_created': '00uv7uac52NTBxe1e2p7',
#              'user_id_modified': '00uv7uac52NTBxe1e2p7'}}

# %%
# Create portfolio.

# Create a Transactions Portfolios API
transaction_portfolio_api = api_factory.build(lusid.api.TransactionPortfoliosApi)

# Attempt to create a Transaction Portfolio
try:
    create_portfolio_response = transaction_portfolio_api.create_portfolio(
        scope=scope,
        create_transaction_portfolio_request=models.CreateTransactionPortfolioRequest(
            display_name=portfolio_name,
            code=portfolio_code,
            description="Joe's demo portfolio.",
            base_currency="GBP",
            created="2020-01-01",
            sub_holding_keys=portfolio_sub_holding_keys,
            #properties=transaction_portfolio_properties,
            instrument_scopes = [
                scope
            ],
        ),
    )

    print(create_portfolio_response)

except lusid.ApiException as e:
    print(json.loads(e.body)["title"])
# Out:
# {'accounting_method': 'Default',
#  'amortisation_method': 'NoAmortisation',
#  'amortisation_rule_set_id': None,
#  'base_currency': 'GBP',
#  'cash_gain_loss_calculation_date': 'Default',
#  'created': datetime.datetime(2020, 1, 1, 0, 0, tzinfo=tzutc()),
#  'description': "Joe's demo portfolio.",
#  'display_name': 'Joe Cockings Demo Portfolio',
#  'href': 'https://fbn-joe.lusid.com/api/api/portfolios/Demo2/JC_UK?asAt=2024-06-11T13%3A09%3A52.7113100%2B00%3A00',
#  'id': {'code': 'JC_UK', 'scope': 'Demo2'},
#  'instrument_event_configuration': {'recipe_id': None,
#                                     'transaction_template_scopes': ['default']},
#  'instrument_scopes': ['Demo2'],
#  'is_derived': False,
#  'links': [{'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/portfolios/Demo2/JC_UK/properties?effectiveAt=2020-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2024-06-11T13%3A09%3A52.7113100%2B00%3A00',
#             'method': 'GET',
#             'relation': 'Properties'},
#            {'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/portfolios/Demo2/JC_UK/commands?toAsAt=2024-06-11T13%3A09%3A52.7113100%2B00%3A00',
#             'method': 'GET',
#             'relation': 'Commands'},
#            {'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/transactionportfolios/Demo2/JC_UK/details?effectiveAt=2020-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2024-06-11T13%3A09%3A52.7113100%2B00%3A00',
#             'method': 'GET',
#             'relation': 'Details'},
#            {'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/transactionportfolios/Demo2/JC_UK/transactions?effectiveAt=2020-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2024-06-11T13%3A09%3A52.7113100%2B00%3A00',
#             'method': 'GET',
#             'relation': 'Transactions'},
#            {'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/transactionportfolios/Demo2/JC_UK/holdings?effectiveAt=2020-01-01T00%3A00%3A00.0000000%2B00%3A00&asAt=2024-06-11T13%3A09%3A52.7113100%2B00%3A00',
#             'method': 'GET',
#             'relation': 'Holdings'},
#            {'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/transactionportfolios/Demo2/JC_UK/holdingsadjustments/2020-01-01T00%3A00%3A00.0000000%2B00%3A00?asAt=2024-06-11T13%3A09%3A52.7113100%2B00%3A00',
#             'method': 'GET',
#             'relation': 'HoldingsAdjustments'},
#            {'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/schemas/entities/Portfolio',
#             'method': 'GET',
#             'relation': 'EntitySchema'},
#            {'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN4A2HUU1K2M:0000001B',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'parent_portfolio_id': None,
#  'properties': None,
#  'relationships': [],
#  'staged_modifications': {'count_pending': 0,
#                           'href_pending': 'https://fbn-joe.lusid.com/api/api/stagedmodifications/?asAt=2024-06-11T13%3A09%3A52.7113100%2B00%3A00&filter=entityUniqueId%20eq%20%27dbddcffe-75c2-417f-8d18-428a4f496a16%20and%20status%20eq%20%27Pending%27',
#                           'ids_previewed': []},
#  'transaction_type_scope': 'default',
#  'type': 'Transaction',
#  'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 9, 52, 711310, tzinfo=tzutc()),
#              'as_at_date': datetime.datetime(2024, 6, 11, 13, 9, 52, 711310, tzinfo=tzutc()),
#              'as_at_modified': datetime.datetime(2024, 6, 11, 13, 9, 52, 711310, tzinfo=tzutc()),
#              'as_at_version_number': 1,
#              'effective_from': datetime.datetime(2020, 1, 1, 0, 0, tzinfo=tzutc()),
#              'entity_unique_id': 'dbddcffe-75c2-417f-8d18-428a4f496a16',
#              'request_id_created': '0HN4A2HUU1K2M:0000001B',
#              'request_id_modified': '0HN4A2HUU1K2M:0000001B',
#              'staged_modification_id_modified': None,
#              'user_id_created': '00uv7uac52NTBxe1e2p7',
#              'user_id_modified': '00uv7uac52NTBxe1e2p7'}}

# %%
# Add instruments to the domain, in the demo scope.

# First generate distinct instruments from the transactions file.

# Create instruments API
instrument_api = api_factory.build(lusid.api.InstrumentsApi)

instrument_keys = [
    "ticker",
    "sedol",
    "instrument_type",
    "instrument_id",
    "name",
    "currency",
]

instrument_identifiers = {
    "ticker": "Isin",
    "sedol": "Sedol",
    "instrument_id": "ClientInternal",
}

instrument_type_identifiers = {
    "equity": "Equity",
    "bond": "Bond"
}

# function to return formatted datetime
def formatted_datetime(date_string):
    day, month, year = date_string.split("/")
    formatted_date = datetime(int(year), int(month), int(day), tzinfo=timezone.utc)
    return formatted_date.isoformat()

def resolve_lusid_instrument_definition(instrument):
    match instrument["instrument_type"]:
        case "equity":
            return models.Equity(
                dom_ccy=instrument["currency"],
                instrument_type=instrument_type_identifiers[instrument["instrument_type"]],
            )
        case "bond":
            return models.Bond(
                dom_ccy = instrument["currency"],
                instrument_type = instrument_type_identifiers[instrument["instrument_type"]],
                start_date = formatted_datetime(instrument["start_date"]),
                maturity_date = formatted_datetime(instrument["maturity_date"]),
                principal = instrument["principal"],
                coupon_rate = float(instrument["coupon"]),
                
                # Default flow conventions
                flow_conventions = models.FlowConventions(
                    currency = instrument["currency"],
                    payment_frequency = "6M",
                    roll_convention = "F",
                    day_count_convention="Actual360",
                    payment_calendars=[],
                    reset_calendars=[]
                )
            )

# define request body dictionary object.
instrument_definitions_request_body = {}

# Read instruments form file into df.
instruments = pd.read_csv('instruments.csv')

#Generate request body.
for enum, instrument in instruments.iterrows():
    
    identifiers = {}

    #Iterate over each instrument key
    for client_ref, lusid_ref in instrument_identifiers.items():
        identifiers[lusid_ref] = models.InstrumentIdValue(
            value=instrument[client_ref],
        )

    instrumentName = instrument["name"]
    instrument_definitions_request_body[f"INS_REQ_{enum}"] = models.InstrumentDefinition(
        name=instrument["name"],
        identifiers=identifiers,
        properties=[
            models.ModelProperty(
                key = f"Instrument/default/Isin",
                value = models.PropertyValue(
                    label_value = instrument["ticker"]
                ),
            ),
            models.ModelProperty(
                key = f"Instrument/default/Sedol",
                value = models.PropertyValue(
                    label_value = instrument["sedol"]
                ),
            ),
            models.ModelProperty(
                key = f"Instrument/{scope}/{inst_prop_rating_code}",
                value = models.PropertyValue(
                    metric_value = models.MetricValue(
                        value = float(instrument["moody"])
                        )
                ),
            )
        ],
        definition=resolve_lusid_instrument_definition(instrument),
    )

print("Now attempting to upsert to LUSID")

# Attempt to upsert the instrument definitions.
try:
    upsert_instruments_response = instrument_api.upsert_instruments(
        scope=scope,
        request_body=instrument_definitions_request_body,
    )

    print(upsert_instruments_response)

except lusid.ApiException as e:
    pp.pprint(f'Exception thrown: {e}')
    pp.pprint(json.loads(e.body)["title"])
# Out:
# Now attempting to upsert to LUSID
# {'failed': {},
#  'href': None,
#  'links': [{'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/schemas/entities/UpsertInstrumentsResponse',
#             'method': 'GET',
#             'relation': 'EntitySchema'},
#            {'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN4A2M0N8RG9:00000049',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'metadata': {'actions': [{'description': 'The request identifiers of Created Instruments',
#  'identifier_type': 'RequestId',
#  'identifiers': ['INS_REQ_3',
#                  'INS_REQ_2',
#                  'INS_REQ_0',
#                  'INS_REQ_7',
#                  'INS_REQ_6',
#                  'INS_REQ_1',
#                  'INS_REQ_4',
#                  'INS_REQ_8',
#                  'INS_REQ_10',
#                  'INS_REQ_9',
#                  'INS_REQ_5'],
#  'type': 'CreatedInstruments'}]},
#  'values': {'INS_REQ_0': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9B?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'EQ_1234',
#                                           'Isin': 'GB0002162385',
#                                           'LusidInstrumentId': 'LUID_00003D9B',
#                                           'Sedol': 'SEDOL1'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9B',
#                           'name': 'Aviva',
#                           'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                           'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                           'key': 'Instrument/Demo2/MoodyRating',
#                                           'value': {'label_value': None,
#                                                     'label_value_set': None,
#                                                     'metric_value': {'unit': None,
#                                                                      'value': 1.0}}}],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '499f3776-2c15-440a-85fe-25c66ac91710',
#                                       'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                       'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_1': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9E?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'EQ_1235',
#                                           'Isin': 'GB0000566504',
#                                           'LusidInstrumentId': 'LUID_00003D9E',
#                                           'Sedol': 'SEDOL2'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9E',
#                           'name': 'BHP',
#                           'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                           'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                           'key': 'Instrument/Demo2/MoodyRating',
#                                           'value': {'label_value': None,
#                                                     'label_value_set': None,
#                                                     'metric_value': {'unit': None,
#                                                                      'value': 4.0}}}],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '8ba4a697-d0c9-4b4a-bb6d-899c6d35ea1b',
#                                       'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                       'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_10': {'asset_class': 'Credit',
#                            'dom_ccy': 'GBP',
#                            'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9H?scope=Demo2',
#                            'identifiers': {'ClientInternal': 'EQ_1250',
#                                            'Isin': 'GB0002404191',
#                                            'LusidInstrumentId': 'LUID_00003D9H',
#                                            'Sedol': 'SEDOL11'},
#                            'instrument_definition': {'calculation_type': 'Standard',
#                                                      'coupon_rate': 6.0,
#                                                      'dom_ccy': 'GBP',
#                                                      'ex_dividend_configuration': None,
#                                                      'ex_dividend_days': None,
#                                                      'first_coupon_pay_date': None,
#                                                      'flow_conventions': {'accrual_date_adjustment': 'Adjusted',
#                                                                           'accrual_day_count_convention': 'Actual360',
#                                                                           'business_day_convention': 'F',
#                                                                           'code': None,
#                                                                           'currency': 'GBP',
#                                                                           'day_count_convention': 'Actual360',
#                                                                           'leap_days_included': True,
#                                                                           'payment_calendars': [],
#                                                                           'payment_frequency': '6M',
#                                                                           'reset_calendars': [],
#                                                                           'reset_days': 0,
#                                                                           'roll_convention': 'F',
#                                                                           'scope': None,
#                                                                           'settle_days': 0},
#                                                      'identifiers': {},
#                                                      'initial_coupon_date': None,
#                                                      'instrument_type': 'Bond',
#                                                      'maturity_date': datetime.datetime(2028, 12, 7, 0, 0, tzinfo=tzutc()),
#                                                      'original_issue_price': None,
#                                                      'principal': 1000000000.0,
#                                                      'rounding_conventions': [],
#                                                      'start_date': datetime.datetime(2004, 12, 13, 0, 0, tzinfo=tzutc())},
#                            'links': None,
#                            'lookthrough_portfolio': None,
#                            'lusid_instrument_id': 'LUID_00003D9H',
#                            'name': 'UK Treasury',
#                            'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                            'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                            'key': 'Instrument/Demo2/MoodyRating',
#                                            'value': {'label_value': None,
#                                                      'label_value_set': None,
#                                                      'metric_value': {'unit': None,
#                                                                       'value': 2.0}}}],
#                            'relationships': [],
#                            'scope': 'Demo2',
#                            'state': 'Active',
#                            'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                        'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                        'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                        'as_at_version_number': 1,
#                                        'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                        'entity_unique_id': '1e573586-5066-4408-b522-73be2a2a6859',
#                                        'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                        'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                        'staged_modification_id_modified': None,
#                                        'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                        'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_2': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9A?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'EQ_1236',
#                                           'Isin': 'GB0031348658',
#                                           'LusidInstrumentId': 'LUID_00003D9A',
#                                           'Sedol': 'SEDOL3'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9A',
#                           'name': 'Barclays',
#                           'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                           'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                           'key': 'Instrument/Demo2/MoodyRating',
#                                           'value': {'label_value': None,
#                                                     'label_value_set': None,
#                                                     'metric_value': {'unit': None,
#                                                                      'value': 3.0}}}],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '30c44291-2a30-4399-ba7e-cb10e0ef61fe',
#                                       'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                       'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_3': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D99?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'EQ_1237',
#                                           'Isin': 'GB0007980591',
#                                           'LusidInstrumentId': 'LUID_00003D99',
#                                           'Sedol': 'SEDOL4'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D99',
#                           'name': 'BP',
#                           'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                           'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                           'key': 'Instrument/Demo2/MoodyRating',
#                                           'value': {'label_value': None,
#                                                     'label_value_set': None,
#                                                     'metric_value': {'unit': None,
#                                                                      'value': 2.0}}}],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '4086963d-3f0e-4971-b415-875f84bb75a8',
#                                       'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                       'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_4': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9F?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'EQ_1238',
#                                           'Isin': 'GB0005405286',
#                                           'LusidInstrumentId': 'LUID_00003D9F',
#                                           'Sedol': 'SEDOL5'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9F',
#                           'name': 'HSBC',
#                           'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                           'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                           'key': 'Instrument/Demo2/MoodyRating',
#                                           'value': {'label_value': None,
#                                                     'label_value_set': None,
#                                                     'metric_value': {'unit': None,
#                                                                      'value': 5.0}}}],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '269ab933-9d59-4969-8309-691f5e230b39',
#                                       'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                       'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_5': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9J?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'EQ_1239',
#                                           'Isin': 'GB0006043169',
#                                           'LusidInstrumentId': 'LUID_00003D9J',
#                                           'Sedol': 'SEDOL6'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9J',
#                           'name': 'Morrisons',
#                           'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                           'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                           'key': 'Instrument/Demo2/MoodyRating',
#                                           'value': {'label_value': None,
#                                                     'label_value_set': None,
#                                                     'metric_value': {'unit': None,
#                                                                      'value': 2.0}}}],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '4ed3715c-3eac-4096-82ed-4bc814e2a8b5',
#                                       'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                       'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_6': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9D?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'EQ_1240',
#                                           'Isin': 'GB0008847096',
#                                           'LusidInstrumentId': 'LUID_00003D9D',
#                                           'Sedol': 'SEDOL7'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9D',
#                           'name': 'Tesco',
#                           'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                           'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                           'key': 'Instrument/Demo2/MoodyRating',
#                                           'value': {'label_value': None,
#                                                     'label_value_set': None,
#                                                     'metric_value': {'unit': None,
#                                                                      'value': 3.0}}}],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '971e0558-906f-4a78-8b39-f8a3b2c118a0',
#                                       'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                       'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_7': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9C?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'EQ_1241',
#                                           'Isin': 'GB00BGDT3G23',
#                                           'LusidInstrumentId': 'LUID_00003D9C',
#                                           'Sedol': 'SEDOL8'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9C',
#                           'name': 'Rightmove',
#                           'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                           'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                           'key': 'Instrument/Demo2/MoodyRating',
#                                           'value': {'label_value': None,
#                                                     'label_value_set': None,
#                                                     'metric_value': {'unit': None,
#                                                                      'value': 2.0}}}],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '49d970bc-0788-4f16-a84e-d3206de92ae7',
#                                       'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                       'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_8': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9G?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'EQ_1242',
#                                           'Isin': 'GB00BH4HKS39',
#                                           'LusidInstrumentId': 'LUID_00003D9G',
#                                           'Sedol': 'SEDOL9'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9G',
#                           'name': 'vodafone',
#                           'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                           'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                           'key': 'Instrument/Demo2/MoodyRating',
#                                           'value': {'label_value': None,
#                                                     'label_value_set': None,
#                                                     'metric_value': {'unit': None,
#                                                                      'value': 2.0}}}],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '3695739e-2e06-4351-bbc2-c6077654fa5f',
#                                       'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                       'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_9': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9I?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'EQ_1243',
#                                           'Isin': 'GB00B1XZS820',
#                                           'LusidInstrumentId': 'LUID_00003D9I',
#                                           'Sedol': 'SEDOL10'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9I',
#                           'name': 'Anglo American plc',
#                           'properties': [{'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                           'effective_until': datetime.datetime(9999, 12, 31, 23, 59, 59, 999999, tzinfo=tzutc()),
#                                           'key': 'Instrument/Demo2/MoodyRating',
#                                           'value': {'label_value': None,
#                                                     'label_value_set': None,
#                                                     'metric_value': {'unit': None,
#                                                                      'value': 3.0}}}],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 12, 3, 322853, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '0d555506-a993-481f-b1eb-dff48cf3aa2d',
#                                       'request_id_created': '0HN4A2M0N8RG9:00000049',
#                                       'request_id_modified': '0HN4A2M0N8RG9:00000049',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}}}}

# %%
# Add transactions.

portfolio_sub_holding_key = portfolio_sub_holding_keys[0]

transactions = pd.read_csv('transactions.csv')

# Generate list of transaction requests.
security_transaction_types = [
    "Buy",
    "Sell",
    "SellShort",
    "Cover"
]

cashflow_transaction_types = [
    "FundsIn",
    "FundsOut"
]

# function to return formatted datetime
def formatted_datetime(date_string):
    day, month, year = date_string.split("/")
    formatted_date = datetime(int(year), int(month), int(day), tzinfo=timezone.utc)
    return formatted_date.isoformat()

# function to resolve correct identifier
def resolve_instrument_identifier(transaction):
    transaction_type = transaction["txn_type"]
    if transaction_type in security_transaction_types: return "Isin"
    elif transaction_type in cashflow_transaction_types: return "Currency"
    # Should crash otherwise.

# function to resolve correct instrument scope
def resolve_instrument_scope(transaction):
    transaction_type = transaction["txn_type"]
    if transaction_type in security_transaction_types: return scope
    elif transaction_type in cashflow_transaction_types: return "default"
    # Should crash otherwise.

def resolve_transaction_price_type(transaction):
    transaction_type = transaction["txn_type"]
    if transaction_type in security_transaction_types:
        if transaction["instrument_type"] == "equity": return "Price"
        if transaction["instrument_type"] == "bond": return "Price"    
    elif transaction_type in cashflow_transaction_types: return "CashFlowPerUnit"
    # Should crash otherwise.

transaction_requests = []

for transaction_number, transaction in transactions.iterrows():
    transactionID = transaction["txn_id"]
    print(f"Creating TransactionRequest object for Transaction ID {transactionID}")
    transaction_requests.append(
        models.TransactionRequest(
            transaction_id = transaction["txn_id"],
            type = transaction["txn_type"],
            instrument_identifiers = {
                f"Instrument/default/{resolve_instrument_identifier(transaction)}": transaction["ticker"],
            },
            transaction_date = formatted_datetime(transaction["txn_trade_date"]),
            settlement_date = formatted_datetime(transaction["txn_settle_date"]),
            units = float(transaction["txn_units"]),
            transaction_price = models.TransactionPrice(
                price = float(transaction["txn_price"]),
                type = resolve_transaction_price_type(transaction)
            ),
            total_consideration = models.CurrencyAndAmount(
                amount = float(transaction["txn_consideration"]),
                currency = transaction["currency"],
            ),
            transaction_currency = transaction["currency"],
            properties = {
                portfolio_sub_holding_key: models.PerpetualProperty(
                    key = portfolio_sub_holding_key,
                    value = models.PropertyValue(
                        label_value = transaction[sub_holding_key_code]
                    ),
                ),
            }
        )
    )

print(transaction_requests)

# Create a Transactions Portfolios API
transaction_portfolio_api = api_factory.build(lusid.api.TransactionPortfoliosApi)

try:
    upsert_transaction = transaction_portfolio_api.upsert_transactions(
        scope=scope, # Scope of the portfolio.
        code=portfolio_code, # Code of the portfolio.
        transaction_request=transaction_requests,
    )

    print(upsert_transaction)

except lusid.ApiException as e:
    pp.pprint(e)
    pp.pprint(json.loads(e.body)["title"])
# Out:
# Creating TransactionRequest object for Transaction ID trd_0001
# Creating TransactionRequest object for Transaction ID trd_0002
# Creating TransactionRequest object for Transaction ID trd_0003
# Creating TransactionRequest object for Transaction ID trd_0004
# Creating TransactionRequest object for Transaction ID trd_0005
# Creating TransactionRequest object for Transaction ID trd_0006
# Creating TransactionRequest object for Transaction ID trd_0007
# Creating TransactionRequest object for Transaction ID trd_0008
# Creating TransactionRequest object for Transaction ID trd_0009
# Creating TransactionRequest object for Transaction ID trd_0010
# Creating TransactionRequest object for Transaction ID trd_0011
# Creating TransactionRequest object for Transaction ID trd_0012
# Creating TransactionRequest object for Transaction ID trd_0022
# Creating TransactionRequest object for Transaction ID trd_0014
# Creating TransactionRequest object for Transaction ID trd_0015
# Creating TransactionRequest object for Transaction ID trd_0016
# Creating TransactionRequest object for Transaction ID trd_0017
# Creating TransactionRequest object for Transaction ID trd_0018
# Creating TransactionRequest object for Transaction ID trd_0019
# Creating TransactionRequest object for Transaction ID trd_0020
# Creating TransactionRequest object for Transaction ID trd_0021
# Creating TransactionRequest object for Transaction ID trd_0061
# Creating TransactionRequest object for Transaction ID trd_0062
# Creating TransactionRequest object for Transaction ID trd_0050
# Creating TransactionRequest object for Transaction ID trd_0051
# [{'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0002162385'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 600000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0001',
#  'transaction_price': {'price': 5.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 120000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0002162385'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 60000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0002',
#  'transaction_price': {'price': 5.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 12000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0000566504'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 1080000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0003',
#  'transaction_price': {'price': 18.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 60000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0000566504'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 1080000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0004',
#  'transaction_price': {'price': 18.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 60000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0031348658'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 300000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0005',
#  'transaction_price': {'price': 2.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 150000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0031348658'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 300000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0006',
#  'transaction_price': {'price': 2.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 150000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0007980591'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 500000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0007',
#  'transaction_price': {'price': 5.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 100000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0007980591'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 500000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0008',
#  'transaction_price': {'price': 5.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 100000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0005405286'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 120000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0009',
#  'transaction_price': {'price': 6.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 20000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0005405286'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 120000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0010',
#  'transaction_price': {'price': 6.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 20000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0006043169'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 360000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0011',
#  'transaction_price': {'price': 2.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 180000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0006043169'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Moderate',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 360000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0012',
#  'transaction_price': {'price': 2.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 180000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0008847096'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Moderate',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 64000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0022',
#  'transaction_price': {'price': 8.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 8000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0008847096'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Moderate',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 36000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0014',
#  'transaction_price': {'price': 9.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 4000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB00BGDT3G23'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Moderate',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 480000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0015',
#  'transaction_price': {'price': 6.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 80000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB00BGDT3G23'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Moderate',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 480000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0016',
#  'transaction_price': {'price': 6.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 80000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB00BH4HKS39'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Moderate',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 450000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0017',
#  'transaction_price': {'price': 1.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 450000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB00BH4HKS39'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Safe',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 450000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0018',
#  'transaction_price': {'price': 1.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 450000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB00B1XZS820'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Safe',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 700000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0019',
#  'transaction_price': {'price': 20.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 35000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB00B1XZS820'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Safe',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 700000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0020',
#  'transaction_price': {'price': 20.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 35000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Currency': 'GBP'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Safe',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2020-05-29T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 12000000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-05-27T00:00:00+00:00',
#  'transaction_id': 'trd_0021',
#  'transaction_price': {'price': 1.0, 'type': 'CashFlowPerUnit'},
#  'type': 'FundsIn',
#  'units': 12000000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Currency': 'GBP'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Moderate',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2020-05-29T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 12000000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-05-27T00:00:00+00:00',
#  'transaction_id': 'trd_0061',
#  'transaction_price': {'price': 1.0, 'type': 'CashFlowPerUnit'},
#  'type': 'FundsIn',
#  'units': 12000000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Currency': 'GBP'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Aggressive',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2020-05-29T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 12000000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-05-27T00:00:00+00:00',
#  'transaction_id': 'trd_0062',
#  'transaction_price': {'price': 1.0, 'type': 'CashFlowPerUnit'},
#  'type': 'FundsIn',
#  'units': 12000000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0002404191'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Safe',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 49500.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0050',
#  'transaction_price': {'price': 99.0, 'type': 'Price'},
#  'type': 'Buy',
#  'units': 50000.0}, {'allocation_id': None,
#  'counterparty_id': None,
#  'custodian_account_id': None,
#  'exchange_rate': None,
#  'instrument_identifiers': {'Instrument/default/Isin': 'GB0002404191'},
#  'order_id': None,
#  'otc_confirmation': None,
#  'properties': {'Transaction/Demo2/strategy': {'key': 'Transaction/Demo2/strategy',
#                                                'value': {'label_value': 'Safe',
#                                                          'label_value_set': None,
#                                                          'metric_value': None}}},
#  'settlement_date': '2024-06-05T00:00:00+00:00',
#  'source': None,
#  'total_consideration': {'amount': 5000.0, 'currency': 'GBP'},
#  'transaction_currency': 'GBP',
#  'transaction_date': '2024-06-03T00:00:00+00:00',
#  'transaction_id': 'trd_0051',
#  'transaction_price': {'price': 100.0, 'type': 'Price'},
#  'type': 'Sell',
#  'units': 5000.0}]
# {'href': 'https://fbn-joe.lusid.com/api/api/transactionportfolios/Demo2/JC_UK/transactions?asAt=2024-06-11T13%3A14%3A09.2531120%2B00%3A00',
#  'links': [{'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/portfolios/Demo2/JC_UK?effectiveAt=2024-06-03T00%3A00%3A00.0000000%2B00%3A00&asAt=2024-06-11T13%3A14%3A09.2531120%2B00%3A00',
#             'method': 'GET',
#             'relation': 'Root'},
#            {'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/schemas/entities/UpsertPortfolioTransactionsResponse',
#             'method': 'GET',
#             'relation': 'EntitySchema'},
#            {'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN49S2DU9V89:000000AF',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'metadata': {},
#  'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 9, 52, 711310, tzinfo=tzutc()),
#              'as_at_date': datetime.datetime(2024, 6, 11, 13, 14, 9, 253112, tzinfo=tzutc()),
#              'as_at_modified': datetime.datetime(2024, 6, 11, 13, 9, 52, 711310, tzinfo=tzutc()),
#              'as_at_version_number': 1,
#              'effective_from': datetime.datetime(2024, 6, 3, 0, 0, tzinfo=tzutc()),
#              'entity_unique_id': 'dbddcffe-75c2-417f-8d18-428a4f496a16',
#              'request_id_created': '0HN4A2HUU1K2M:0000001B',
#              'request_id_modified': '0HN4A2HUU1K2M:0000001B',
#              'staged_modification_id_modified': None,
#              'user_id_created': '00uv7uac52NTBxe1e2p7',
#              'user_id_modified': '00uv7uac52NTBxe1e2p7'}}

# %%
# Upsert quotes.

quote_provider = "Client"
quote_source = quote_provider

symbology = "Isin"

# function to return formatted datetime
def formatted_datetime(date_string):
    formatted_date = datetime.strptime(date_string, '%d-%b-%y')
    formatted_date = formatted_date.replace(tzinfo=timezone.utc)

    return formatted_date.isoformat()

# Create an API factory for interacting with the LUSID APIs
quotes_api = api_factory.build(lusid.api.QuotesApi)

# Read quotes from csv.
quotes = pd.read_csv('quotes.csv')

quote_fields = [
    "bid",
    "mid",
    "ask",
]

quote_upsert = {}

for row_index, quote in quotes.iterrows():
    for quote_field in quote_fields:
        quote_upsert["QUOTE_" + quote_field + "_" + str(row_index)] = models.UpsertQuoteRequest(
            quote_id = models.QuoteId(
                quote_series_id = models.QuoteSeriesId(
                    provider = quote_provider,
                    price_source = quote_source,
                    instrument_id = quote["ISIN"],
                    instrument_id_type = symbology,
                    quote_type = "Price",
                    field = quote_field,
                ),
                effective_at = formatted_datetime(quote["quote_date"])
            ),
            metric_value = models.MetricValue(
                value = float(quote[quote_field]),
                unit = "GBP",
            )
        )

print(f'Quote upsert is :')
for value in quote_upsert.values():
    print(value.to_str())
    
print(quote_upsert)

try:
    quote_upsert_response = quotes_api.upsert_quotes(
        scope = scope,
        request_body = quote_upsert,
    )

    print(quote_upsert_response)

except Exception as e:
    print(f'Thrown exception: {e}')
# Out:
# Quote upsert is :
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.29},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0002162385',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.3},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0002162385',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.31},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0002162385',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 12.81},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB00BH0P3Z91',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 12.87},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB00BH0P3Z91',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 12.93},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB00BH0P3Z91',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 0.88},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0031348658',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.88},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0031348658',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 0.88},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0031348658',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 3.06},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0007980591',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 3.08},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0007980591',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 3.1},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0007980591',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.0},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0005405286',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.02},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0005405286',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.04},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0005405286',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.87},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0006043169',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.88},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0006043169',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.89},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0006043169',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.35},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0008847096',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.36},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0008847096',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.37},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0008847096',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.63},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB00BGDT3G23',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.65},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB00BGDT3G23',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.67},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB00BGDT3G23',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.08},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB00BH4HKS39',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.09},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB00BH4HKS39',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.1},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB00BH4HKS39',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 13.9},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB00B1XZS820',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 13.97},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB00B1XZS820',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 14.04},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB00B1XZS820',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 5.3},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0000566504',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 5.9},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0000566504',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 6.7},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0000566504',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 98.0},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0002404191',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 99.0},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0002404191',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 100.0},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0002404191',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}
# {'QUOTE_bid_0': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.29},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0002162385',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_0': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.3},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0002162385',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_0': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.31},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0002162385',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_1': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 12.81},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB00BH0P3Z91',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_1': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 12.87},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB00BH0P3Z91',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_1': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 12.93},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB00BH0P3Z91',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_2': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 0.88},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0031348658',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_2': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.88},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0031348658',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_2': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 0.88},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0031348658',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_3': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 3.06},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0007980591',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_3': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 3.08},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0007980591',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_3': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 3.1},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0007980591',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_4': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.0},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0005405286',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_4': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.02},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0005405286',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_4': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.04},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0005405286',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_5': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.87},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0006043169',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_5': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.88},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0006043169',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_5': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.89},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0006043169',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_6': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.35},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0008847096',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_6': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.36},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0008847096',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_6': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 2.37},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0008847096',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_7': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.63},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB00BGDT3G23',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_7': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.65},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB00BGDT3G23',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_7': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 4.67},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB00BGDT3G23',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_8': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.08},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB00BH4HKS39',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_8': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.09},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB00BH4HKS39',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_8': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 1.1},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB00BH4HKS39',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_9': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 13.9},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB00B1XZS820',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_9': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 13.97},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB00B1XZS820',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_9': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 14.04},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB00B1XZS820',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_10': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 5.3},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0000566504',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_10': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 5.9},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0000566504',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_10': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 6.7},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0000566504',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_bid_11': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 98.0},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'bid',
#                                   'instrument_id': 'GB0002404191',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_mid_11': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 99.0},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'mid',
#                                   'instrument_id': 'GB0002404191',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}, 'QUOTE_ask_11': {'lineage': None,
#  'metric_value': {'unit': 'GBP', 'value': 100.0},
#  'quote_id': {'effective_at': '2024-06-09T00:00:00+00:00',
#               'quote_series_id': {'field': 'ask',
#                                   'instrument_id': 'GB0002404191',
#                                   'instrument_id_type': 'Isin',
#                                   'price_source': 'Client',
#                                   'provider': 'Client',
#                                   'quote_type': 'Price'}},
#  'scale_factor': None}}
# {'failed': {},
#  'href': None,
#  'links': [{'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN49S2DU9VE6:00000021',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'values': {'QUOTE_ask_0': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 2.31},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'ask',
#                                                              'instrument_id': 'GB0002162385',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_ask_1': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 12.93},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'ask',
#                                                              'instrument_id': 'GB00BH0P3Z91',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_ask_10': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                              'cut_label': '',
#                              'lineage': '',
#                              'metric_value': {'unit': 'GBP', 'value': 6.7},
#                              'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                           'quote_series_id': {'field': 'ask',
#                                                               'instrument_id': 'GB0000566504',
#                                                               'instrument_id_type': 'Isin',
#                                                               'price_source': 'Client',
#                                                               'provider': 'Client',
#                                                               'quote_type': 'Price'}},
#                              'scale_factor': None,
#                              'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_ask_11': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                              'cut_label': '',
#                              'lineage': '',
#                              'metric_value': {'unit': 'GBP', 'value': 100.0},
#                              'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                           'quote_series_id': {'field': 'ask',
#                                                               'instrument_id': 'GB0002404191',
#                                                               'instrument_id_type': 'Isin',
#                                                               'price_source': 'Client',
#                                                               'provider': 'Client',
#                                                               'quote_type': 'Price'}},
#                              'scale_factor': None,
#                              'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_ask_2': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 0.88},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'ask',
#                                                              'instrument_id': 'GB0031348658',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_ask_3': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 3.1},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'ask',
#                                                              'instrument_id': 'GB0007980591',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_ask_4': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 4.04},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'ask',
#                                                              'instrument_id': 'GB0005405286',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_ask_5': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 1.89},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'ask',
#                                                              'instrument_id': 'GB0006043169',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_ask_6': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 2.37},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'ask',
#                                                              'instrument_id': 'GB0008847096',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_ask_7': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 4.67},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'ask',
#                                                              'instrument_id': 'GB00BGDT3G23',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_ask_8': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 1.1},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'ask',
#                                                              'instrument_id': 'GB00BH4HKS39',
#                                                              'instrument_id_type': 'Isin',
# ...
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 2.35},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'bid',
#                                                              'instrument_id': 'GB0008847096',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_bid_7': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 4.63},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'bid',
#                                                              'instrument_id': 'GB00BGDT3G23',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_bid_8': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 1.08},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'bid',
#                                                              'instrument_id': 'GB00BH4HKS39',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_bid_9': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 13.9},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'bid',
#                                                              'instrument_id': 'GB00B1XZS820',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_0': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 2.3},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'mid',
#                                                              'instrument_id': 'GB0002162385',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_1': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 12.87},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'mid',
#                                                              'instrument_id': 'GB00BH0P3Z91',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_10': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                              'cut_label': '',
#                              'lineage': '',
#                              'metric_value': {'unit': 'GBP', 'value': 5.9},
#                              'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                           'quote_series_id': {'field': 'mid',
#                                                               'instrument_id': 'GB0000566504',
#                                                               'instrument_id_type': 'Isin',
#                                                               'price_source': 'Client',
#                                                               'provider': 'Client',
#                                                               'quote_type': 'Price'}},
#                              'scale_factor': None,
#                              'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_11': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                              'cut_label': '',
#                              'lineage': '',
#                              'metric_value': {'unit': 'GBP', 'value': 99.0},
#                              'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                           'quote_series_id': {'field': 'mid',
#                                                               'instrument_id': 'GB0002404191',
#                                                               'instrument_id_type': 'Isin',
#                                                               'price_source': 'Client',
#                                                               'provider': 'Client',
#                                                               'quote_type': 'Price'}},
#                              'scale_factor': None,
#                              'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_2': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 1.88},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'mid',
#                                                              'instrument_id': 'GB0031348658',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_3': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 3.08},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'mid',
#                                                              'instrument_id': 'GB0007980591',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_4': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 4.02},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'mid',
#                                                              'instrument_id': 'GB0005405286',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_5': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 1.88},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'mid',
#                                                              'instrument_id': 'GB0006043169',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_6': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 2.36},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'mid',
#                                                              'instrument_id': 'GB0008847096',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_7': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 4.65},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'mid',
#                                                              'instrument_id': 'GB00BGDT3G23',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_8': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 1.09},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'mid',
#                                                              'instrument_id': 'GB00BH4HKS39',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'},
#             'QUOTE_mid_9': {'as_at': datetime.datetime(2024, 6, 11, 13, 16, 13, 409716, tzinfo=tzutc()),
#                             'cut_label': '',
#                             'lineage': '',
#                             'metric_value': {'unit': 'GBP', 'value': 13.97},
#                             'quote_id': {'effective_at': '2024-06-09T00:00:00.0000000+00:00',
#                                          'quote_series_id': {'field': 'mid',
#                                                              'instrument_id': 'GB00B1XZS820',
#                                                              'instrument_id_type': 'Isin',
#                                                              'price_source': 'Client',
#                                                              'provider': 'Client',
#                                                              'quote_type': 'Price'}},
#                             'scale_factor': None,
#                             'uploaded_by': '00uv7uac52NTBxe1e2p7'}}}

# %%
# Upload pricing curve

def formatted_datetime(date_string):
    day, month, year = date_string.split("/")
    formatted_date = datetime(int(year), int(month), int(day), tzinfo=timezone.utc)
    return formatted_date.isoformat()

complex_md_api = api_factory.build(lusid.ComplexMarketDataApi)


with open('curve.json') as curve_data_file:
    curve_data = json.load(curve_data_file)

pp.pprint(curve_data)

discount_rates = pd.read_csv('discount_rate_curve.csv')


for discount_rate_index, discount_rate in discount_rates.iterrows():
    curve_data["GBP/GBPOIS"]["marketData"]["dates"].append(formatted_datetime(discount_rate["date"]))
    curve_data["GBP/GBPOIS"]["marketData"]["discountFactors"].append(float(discount_rate["factor"]))

pp.pprint(curve_data)

request_body = curve_data

try:
    upload_curve = complex_md_api.upsert_complex_market_data(scope, request_body)

    print(upload_curve)

except Exception as e:
    print(f'Thrown exception: {e}')
# Out:
# {'GBP/GBPOIS': {'marketData': {'baseDate': '2024-06-10T00:00:00.0000000+00:00',
#                                'dates': [],
#                                'discountFactors': [],
#                                'lineage': 'SomeLineage',
#                                'marketDataOptions': {'backExtrapolationType': 'None',
#                                                      'dayCountConvention': 'Actual365',
#                                                      'frontExtrapolationType': 'Linear',
#                                                      'marketDataOptionsType': 'CurveOptions'},
#                                'marketDataType': 'DiscountFactorCurveData'},
#                 'marketDataId': {'effectiveAt': '2024-06-10T00:00:00.0000000+00:00',
#                                  'marketAsset': 'GBP/GBPOIS',
#                                  'priceSource': 'Client',
#                                  'provider': 'Client'}}}
# {'GBP/GBPOIS': {'marketData': {'baseDate': '2024-06-10T00:00:00.0000000+00:00',
#                                'dates': ['2024-07-19T00:00:00+00:00',
#                                          '2024-08-19T00:00:00+00:00',
#                                          '2024-09-19T00:00:00+00:00',
#                                          '2024-10-19T00:00:00+00:00',
#                                          '2024-11-19T00:00:00+00:00',
#                                          '2024-12-19T00:00:00+00:00',
#                                          '2025-01-19T00:00:00+00:00',
#                                          '2025-02-19T00:00:00+00:00',
#                                          '2025-03-19T00:00:00+00:00',
#                                          '2025-04-19T00:00:00+00:00',
#                                          '2025-05-19T00:00:00+00:00',
#                                          '2025-06-19T00:00:00+00:00',
#                                          '2025-07-19T00:00:00+00:00',
#                                          '2025-08-19T00:00:00+00:00',
#                                          '2025-09-19T00:00:00+00:00',
#                                          '2025-10-19T00:00:00+00:00',
#                                          '2025-11-19T00:00:00+00:00',
#                                          '2025-12-19T00:00:00+00:00',
#                                          '2026-01-19T00:00:00+00:00',
#                                          '2026-02-19T00:00:00+00:00',
#                                          '2026-03-19T00:00:00+00:00',
#                                          '2026-04-19T00:00:00+00:00',
#                                          '2026-05-19T00:00:00+00:00',
#                                          '2026-06-19T00:00:00+00:00',
#                                          '2026-07-19T00:00:00+00:00',
#                                          '2026-08-19T00:00:00+00:00',
#                                          '2026-09-19T00:00:00+00:00',
#                                          '2026-10-19T00:00:00+00:00',
#                                          '2026-11-19T00:00:00+00:00',
#                                          '2026-12-19T00:00:00+00:00',
#                                          '2027-01-19T00:00:00+00:00',
#                                          '2027-02-19T00:00:00+00:00',
#                                          '2027-03-19T00:00:00+00:00',
#                                          '2027-04-19T00:00:00+00:00',
#                                          '2027-05-19T00:00:00+00:00',
#                                          '2027-06-19T00:00:00+00:00',
#                                          '2027-07-19T00:00:00+00:00',
#                                          '2027-08-19T00:00:00+00:00',
#                                          '2027-09-19T00:00:00+00:00',
#                                          '2027-10-19T00:00:00+00:00',
#                                          '2027-11-19T00:00:00+00:00',
#                                          '2027-12-19T00:00:00+00:00',
#                                          '2028-01-19T00:00:00+00:00',
#                                          '2028-02-19T00:00:00+00:00',
#                                          '2028-03-19T00:00:00+00:00',
#                                          '2028-04-19T00:00:00+00:00',
#                                          '2028-05-19T00:00:00+00:00',
#                                          '2028-06-19T00:00:00+00:00',
#                                          '2028-07-19T00:00:00+00:00',
#                                          '2028-08-19T00:00:00+00:00',
#                                          '2028-09-19T00:00:00+00:00',
#                                          '2028-10-19T00:00:00+00:00',
#                                          '2028-11-19T00:00:00+00:00',
#                                          '2028-12-19T00:00:00+00:00',
#                                          '2029-01-19T00:00:00+00:00',
#                                          '2029-02-19T00:00:00+00:00',
#                                          '2029-03-19T00:00:00+00:00',
#                                          '2029-04-19T00:00:00+00:00',
#                                          '2029-05-19T00:00:00+00:00',
#                                          '2029-06-19T00:00:00+00:00'],
#                                'discountFactors': [0.9998,
#                                                    0.9997,
#                                                    0.9996,
#                                                    0.9995,
#                                                    0.9994,
#                                                    0.9993,
#                                                    0.9992,
#                                                    0.9991,
#                                                    0.999,
#                                                    0.9989,
#                                                    0.9988,
#                                                    0.9987,
#                                                    0.9986,
#                                                    0.9985,
#                                                    0.9984,
#                                                    0.9983,
#                                                    0.9982,
#                                                    0.9981,
#                                                    0.998,
#                                                    0.9979,
#                                                    0.9978,
#                                                    0.9977,
#                                                    0.9976,
#                                                    0.9975,
#                                                    0.9974,
#                                                    0.9973,
#                                                    0.9972,
#                                                    0.9971,
#                                                    0.997,
#                                                    0.9969,
#                                                    0.9968,
#                                                    0.9967,
#                                                    0.9966,
#                                                    0.9965,
#                                                    0.9964,
#                                                    0.9963,
#                                                    0.9962,
#                                                    0.9961,
#                                                    0.996,
#                                                    0.9959,
#                                                    0.9958,
#                                                    0.9957,
#                                                    0.9956,
#                                                    0.9955,
#                                                    0.9954,
#                                                    0.9953,
#                                                    0.9952,
#                                                    0.9951,
#                                                    0.995,
#                                                    0.9949,
#                                                    0.9948,
#                                                    0.9947,
#                                                    0.9946,
#                                                    0.9945,
#                                                    0.9944,
#                                                    0.9943,
#                                                    0.9942,
#                                                    0.9941,
#                                                    0.994,
#                                                    0.9939],
#                                'lineage': 'SomeLineage',
#                                'marketDataOptions': {'backExtrapolationType': 'None',
#                                                      'dayCountConvention': 'Actual365',
#                                                      'frontExtrapolationType': 'Linear',
#                                                      'marketDataOptionsType': 'CurveOptions'},
#                                'marketDataType': 'DiscountFactorCurveData'},
#                 'marketDataId': {'effectiveAt': '2024-06-10T00:00:00.0000000+00:00',
#                                  'marketAsset': 'GBP/GBPOIS',
#                                  'priceSource': 'Client',
#                                  'provider': 'Client'}}}
# Thrown exception: (403)
# Reason: Forbidden
# HTTP response headers: HTTPHeaderDict({'Date': 'Tue, 11 Jun 2024 13:19:31 GMT', 'Content-Type': 'application/problem+json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'x-rate-limit-limit': '1m', 'x-rate-limit-remaining': '4999', 'x-rate-limit-reset': '2024-06-11T13:20:30.9583149Z', 'lusid-meta-success': 'False', 'lusid-meta-requestid': '0HN4A19IRLJPF:000000B0', 'lusid-meta-correlationid': '0HN4A19IRLJPF:000000B0', 'lusid-meta-duration': '136', 'x-envoy-upstream-service-time': '151', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains', 'Server': 'FINBOURNE', 'Content-Security-Policy': "default-src 'self' https://*.lusid.com https://*.finbourne.com; script-src 'unsafe-inline' 'self' https://*.lusid.com https://*.finbourne.com https://editor.swagger.io; font-src 'self' fonts.googleapis.com; img-src data: 'self' https://*.lusid.com https://*.finbourne.com https://validator.swagger.io; style-src 'unsafe-inline' 'self' https://*.lusid.com https://*.finbourne.com; report-uri https://lusid.report-uri.com/r/d/csp/enforce", 'X-Frame-Options': 'SAMEORIGIN', 'Permissions-Policy': 'accelerometer=(), ambient-light-sensor=(), autoplay=(self), battery=(), camera=(), cross-origin-isolated=(self), display-capture=(), document-domain=*, encrypted-media=(), execution-while-not-rendered=(), execution-while-out-of-viewport=(), fullscreen=(self), geolocation=(self), gyroscope=(), keyboard-map=(), magnetometer=(), microphone=(), midi=(), navigation-override=(), payment=(), picture-in-picture=(), publickey-credentials-get=(), screen-wake-lock=(), sync-xhr=(), usb=(), web-share=(), xr-spatial-tracking=()', 'Referrer-Policy': 'strict-origin-when-cross-origin', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'Expect-CT': "max-age=3600, enforce, report-uri='https://lusid.report-uri.com/r/d/ct/enforce'", 'Access-Control-Max-Age': '600', 'Content-Encoding': 'gzip'})
# HTTP response body: {"name":"AccessDenied","errorDetails":[],"code":186,"type":"https://docs.lusid.com/#section/Error-Codes/186","title":"Access cannot be granted","status":403,"detail":"Access to perform the requested action cannot be granted because your organisation does not have a required licence. Please contact FINBOURNE Support.","instance":"https://fbn-joe.lusid.com/app/insights/logs/0HN4A19IRLJPF:000000B0","extensions":{}}

# %%
#upsert recipe using market pricings

recipe_code = "standard-recipe-marketprice"

# Create an API factory for interacting with the LUSID APIs
config_recipe_api = api_factory.build(lusid.ConfigurationRecipeApi)

with open('market_recipe.json') as discount_recipe_file:
    recipe_request = json.load(discount_recipe_file)
pp.pprint(recipe_request)

upsert_recipe_request = recipe_request

try:
    recipe_upsert_response = config_recipe_api.upsert_configuration_recipe(
        upsert_recipe_request,
    )

    print(recipe_upsert_response)

except Exception as e:
    print(f'Thrown exception: {e}')



    #metadata mismatch Dim:0,Units:(LUID_00003D8X) != Dim:0,Units:(CCY_GBP).
#metadata mismatch Dim:0,Units:(LUID_00003D8F) != Dim:0,Units:(LUID_00003D8D).
# Out:
# {'configurationRecipe': {'aggregation': {'options': {'allowPartialEntitlementSuccess': False,
#                                                      'applyIso4217Rounding': False,
#                                                      'useAnsiLikeSyntax': False}},
#                          'code': 'standard-recipe',
#                          'description': 'Standard recipe configuration',
#                          'holding': {'taxLotLevelHoldings': True},
#                          'market': {'groupedMarketRules': [],
#                                     'marketRules': [{'dataScope': 'Demo2',
#                                                      'field': 'mid',
#                                                      'key': 'Quote.Isin.*',
#                                                      'priceSource': 'Client',
#                                                      'quoteType': 'Price',
#                                                      'sourceSystem': 'Lusid',
#                                                      'supplier': 'Client'}],
#                                     'options': {'attemptToInferMissingFx': False,
#                                                 'calendarScope': 'CoppClarkHolidayCalendars',
#                                                 'conventionScope': 'Conventions',
#                                                 'defaultInstrumentCodeType': 'Isin',
#                                                 'defaultScope': 'Demo2',
#                                                 'defaultSupplier': 'Client'},
#                                     'specificRules': [],
#                                     'suppliers': {}},
#                          'pricing': {'modelChoice': {},
#                                      'modelRules': [{'instrumentType': 'Bond',
#                                                      'modelName': 'SimpleStatic',
#                                                      'supplier': 'Lusid'}],
#                                      'options': {'allowAnyInstrumentsWithSecUidToPriceOffLookup': False,
#                                                  'allowPartiallySuccessfulEvaluation': True,
#                                                  'conservedQuantityForLookthroughExpansion': 'PV',
#                                                  'enableUseOfCachedUnitResults': False,
#                                                  'modelSelection': {'library': 'Lusid',
#                                                                     'model': 'SimpleStatic'},
#                                                  'produceSeparateResultForLinearOtcLegs': False,
#                                                  'removeContingentCashflowsInPaymentDiary': False,
#                                                  'useChildSubHoldingKeysForPortfolioExpansion': False,
#                                                  'useInstrumentTypeToDeterminePricer': False,
#                                                  'validateDomesticAndQuoteCurrenciesAreConsistent': False,
#                                                  'windowValuationOnInstrumentStartEnd': False},
#                                      'resultDataRules': []},
#                          'scope': 'Demo2'}}
# {'href': None,
#  'links': [{'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN4A2M0N8RK7:00000028',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'value': datetime.datetime(2024, 6, 11, 13, 23, 38, 447983, tzinfo=tzutc())}

# %%
#upsert recipe using market pricing and CTVOM discounting.

# Create an API factory for interacting with the LUSID APIs
config_recipe_api = api_factory.build(lusid.ConfigurationRecipeApi)

with open('discount_recipe.json') as discount_recipe_file:
    recipe_request = json.load(discount_recipe_file)
pp.pprint(recipe_request)

upsert_recipe_request = recipe_request

try:
    recipe_upsert_response = config_recipe_api.upsert_configuration_recipe(
        upsert_recipe_request,
    )

    print(recipe_upsert_response)

except Exception as e:
    print(f'Thrown exception: {e}')
# Out:
# {'configurationRecipe': {'aggregation': {'options': {'allowPartialEntitlementSuccess': False,
#                                                      'applyIso4217Rounding': False,
#                                                      'useAnsiLikeSyntax': False}},
#                          'code': 'standard-recipe-discounting',
#                          'description': 'Standard recipe configuration',
#                          'holding': {'taxLotLevelHoldings': True},
#                          'market': {'groupedMarketRules': [],
#                                     'marketRules': [{'dataScope': 'Demo',
#                                                      'field': 'mid',
#                                                      'key': 'Quote.Isin.*',
#                                                      'priceSource': 'Client',
#                                                      'quoteType': 'Price',
#                                                      'sourceSystem': 'Lusid',
#                                                      'supplier': 'Client'}],
#                                     'options': {'attemptToInferMissingFx': False,
#                                                 'calendarScope': 'CoppClarkHolidayCalendars',
#                                                 'conventionScope': 'Conventions',
#                                                 'defaultInstrumentCodeType': 'Isin',
#                                                 'defaultScope': 'Demo',
#                                                 'defaultSupplier': 'Client'},
#                                     'specificRules': [],
#                                     'suppliers': {}},
#                          'pricing': {'modelChoice': {},
#                                      'modelRules': [{'instrumentType': 'Bond',
#                                                      'modelName': 'ConstantTimeValueOfMoney',
#                                                      'supplier': 'Lusid'}],
#                                      'options': {'allowAnyInstrumentsWithSecUidToPriceOffLookup': False,
#                                                  'allowPartiallySuccessfulEvaluation': True,
#                                                  'conservedQuantityForLookthroughExpansion': 'PV',
#                                                  'enableUseOfCachedUnitResults': False,
#                                                  'modelSelection': {'library': 'Lusid',
#                                                                     'model': 'SimpleStatic'},
#                                                  'produceSeparateResultForLinearOtcLegs': False,
#                                                  'removeContingentCashflowsInPaymentDiary': False,
#                                                  'useChildSubHoldingKeysForPortfolioExpansion': False,
#                                                  'useInstrumentTypeToDeterminePricer': False,
#                                                  'validateDomesticAndQuoteCurrenciesAreConsistent': False,
#                                                  'windowValuationOnInstrumentStartEnd': False},
#                                      'resultDataRules': []},
#                          'scope': 'Demo'}}
# {'href': None,
#  'links': [{'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN49TF02OFFE:000000BA',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'value': datetime.datetime(2024, 6, 11, 11, 37, 14, 705598, tzinfo=tzutc())}

# %%
# Define a reference portfolio.

def formatted_datetime(date_string):
    formatted_date = datetime.strptime(date_string, '%d-%b-%y')
    formatted_date = formatted_date.replace(tzinfo=timezone.utc)

    return formatted_date.isoformat()

reference_portfolio_code = 'SP500'
reference_portfolio_description =  "S&P 500 Index"
reference_portfolio_display_name = "S&P 500 Tracker"

# Create an API for interacting with the LUSID APIs
reference_portfolio_api = api_factory.build(lusid.ReferencePortfolioApi)

try:
    reference_portfolio_creation_response = reference_portfolio_api.create_reference_portfolio(
        scope = scope,
        create_reference_portfolio_request = models.CreateReferencePortfolioRequest(
            display_name = reference_portfolio_display_name,
            description = reference_portfolio_description,
            code=reference_portfolio_code,
            created=formatted_datetime('05-Jun-10'),
        )
    )

    print(reference_portfolio_creation_response)

except Exception as e:
    pp.pprint(f'Thrown exception {e}')
# Out:
# {'accounting_method': 'Default',
#  'amortisation_method': 'NoAmortisation',
#  'amortisation_rule_set_id': None,
#  'base_currency': 'ZZZ',
#  'cash_gain_loss_calculation_date': 'Default',
#  'created': datetime.datetime(2010, 6, 5, 0, 0, tzinfo=tzutc()),
#  'description': 'S&P 500 Index',
#  'display_name': 'S&P 500 Tracker',
#  'href': 'https://fbn-joe.lusid.com/api/api/portfolios/Demo2/SP500?effectiveAt=2010-06-05T00%3A00%3A00.0000000%2B00%3A00&asAt=2024-06-11T13%3A46%3A05.1802320%2B00%3A00',
#  'id': {'code': 'SP500', 'scope': 'Demo2'},
#  'instrument_event_configuration': {'recipe_id': None,
#                                     'transaction_template_scopes': ['default']},
#  'instrument_scopes': [],
#  'is_derived': False,
#  'links': [{'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/referenceportfolios/Demo2/SP500/constituents?asAt=2024-06-11T13%3A46%3A05.1802320%2B00%3A00',
#             'method': 'GET',
#             'relation': 'Constituents'},
#            {'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/portfolios/Demo2/SP500/properties?effectiveAt=2010-06-05T00%3A00%3A00.0000000%2B00%3A00&asAt=2024-06-11T13%3A46%3A05.1802320%2B00%3A00',
#             'method': 'GET',
#             'relation': 'Properties'},
#            {'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/schemas/entities/Portfolio',
#             'method': 'GET',
#             'relation': 'EntitySchema'},
#            {'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN49S2DU9VL7:00000045',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'parent_portfolio_id': None,
#  'properties': None,
#  'relationships': [],
#  'staged_modifications': {'count_pending': 0,
#                           'href_pending': 'https://fbn-joe.lusid.com/api/api/stagedmodifications/?asAt=2024-06-11T13%3A46%3A05.1802320%2B00%3A00&filter=entityUniqueId%20eq%20%27c2fa0dcc-36f9-4d32-bad9-290c236bf2a5%20and%20status%20eq%20%27Pending%27',
#                           'ids_previewed': []},
#  'transaction_type_scope': None,
#  'type': 'Reference',
#  'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 46, 5, 180232, tzinfo=tzutc()),
#              'as_at_date': datetime.datetime(2024, 6, 11, 13, 46, 5, 180232, tzinfo=tzutc()),
#              'as_at_modified': datetime.datetime(2024, 6, 11, 13, 46, 5, 180232, tzinfo=tzutc()),
#              'as_at_version_number': 1,
#              'effective_from': datetime.datetime(2010, 6, 5, 0, 0, tzinfo=tzutc()),
#              'entity_unique_id': 'c2fa0dcc-36f9-4d32-bad9-290c236bf2a5',
#              'request_id_created': '0HN49S2DU9VL7:00000045',
#              'request_id_modified': '0HN49S2DU9VL7:00000045',
#              'staged_modification_id_modified': None,
#              'user_id_created': '00uv7uac52NTBxe1e2p7',
#              'user_id_modified': '00uv7uac52NTBxe1e2p7'}}

# %%
# Add instrument defs of constituent portfolio to lusid.

instrument_keys = [
    "ticker",
    "sedol",
    "instrument_type",
    "instrument_id",
    "name",
    "currency",
]

instrument_identifiers = {
    "ticker": "Isin",
    "instrument_id": "ClientInternal",
}

instrument_type_identifiers = {
    "equity": "Equity",
    "bond": "Bond"
}

# function to return formatted datetime
def formatted_datetime(date_string):
    day, month, year = date_string.split("/")
    formatted_date = datetime(int(year), int(month), int(day), tzinfo=timezone.utc)
    return formatted_date.isoformat()

def resolve_lusid_instrument_definition(instrument):
    match instrument["instrument_type"]:
        case "equity":
            return models.Equity(
                dom_ccy=instrument["currency"],
                instrument_type=instrument_type_identifiers[instrument["instrument_type"]],
            )
        case "bond":
            return models.Bond(
                dom_ccy = instrument["currency"],
                instrument_type = instrument_type_identifiers[instrument["instrument_type"]],
                start_date = formatted_datetime(instrument["start_date"]),
                maturity_date = formatted_datetime(instrument["maturity_date"]),
                principal = instrument["principal"],
                coupon_rate = float(instrument["coupon"]),
                
                # Default flow conventions
                flow_conventions = models.FlowConventions(
                    currency = instrument["currency"],
                    payment_frequency = "6M",
                    roll_convention = "F",
                    day_count_convention="Actual360",
                    payment_calendars=[],
                    reset_calendars=[]
                )
            )

# define request body dictionary object.
instrument_definitions_request_body = {}

instruments = pd.read_csv('sp500constituents.csv')

#Generate request body.
for enum, instrument in instruments.iterrows():
    
    identifiers = {}

    #Iterate over each instrument key
    for client_ref, lusid_ref in instrument_identifiers.items():
        identifiers[lusid_ref] = models.InstrumentIdValue(
            value=instrument[client_ref],
        )
        #print(f"instrument_identifier {instrument_identifier} set as.")
        #print(instrument[instrument_identifier])
        #print("with type")
        #print(type(instrument[instrument_identifier]))


    instrumentName = instrument["name"]
    #print(f"name of instrument in loop is {instrumentName} with type {type(instrumentName)})")
    #print("Instrument name is")
    #print(instrument["name"])
    instrument_definitions_request_body[f"INS_REQ_{enum}"] = models.InstrumentDefinition(
        name=instrument["name"],
        identifiers=identifiers,
        properties=[
            models.ModelProperty(
                key = f"Instrument/default/Isin",
                value = models.PropertyValue(
                    label_value = instrument["ticker"]
                ),
            )
        ],
        definition=resolve_lusid_instrument_definition(instrument),
    )


#print(instrument_definitions_request_body)

print("Now attempting to upsert to LUSID")

# Attempt to upsert the instrument definitions.
try:
    upsert_instruments_response = instrument_api.upsert_instruments(
        scope=scope,
        request_body=instrument_definitions_request_body,
    )

    print(upsert_instruments_response)

except lusid.ApiException as e:
    pp.pprint(f'Exception thrown: {e}')
    pp.pprint(json.loads(e.body)["title"])
# Out:
# Now attempting to upsert to LUSID
# {'failed': {},
#  'href': None,
#  'links': [{'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/schemas/entities/UpsertInstrumentsResponse',
#             'method': 'GET',
#             'relation': 'EntitySchema'},
#            {'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN49TF02OGJM:0000002C',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'metadata': {'actions': [{'description': 'The request identifiers of Created Instruments',
#  'identifier_type': 'RequestId',
#  'identifiers': ['INS_REQ_0', 'INS_REQ_1', 'INS_REQ_2'],
#  'type': 'CreatedInstruments'}]},
#  'values': {'INS_REQ_0': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9K?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'US02079K3059',
#                                           'Isin': 'US02079K3059',
#                                           'LusidInstrumentId': 'LUID_00003D9K'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9K',
#                           'name': 'Alphabet',
#                           'properties': [],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 46, 32, 954072, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 46, 32, 954072, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 46, 32, 954072, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': 'ab9315bf-a2ff-4ade-a6ad-a39a2f6f7997',
#                                       'request_id_created': '0HN49TF02OGJM:0000002C',
#                                       'request_id_modified': '0HN49TF02OGJM:0000002C',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_1': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9L?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'US0231351067',
#                                           'Isin': 'US0231351067',
#                                           'LusidInstrumentId': 'LUID_00003D9L'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9L',
#                           'name': 'Amazon',
#                           'properties': [],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 46, 32, 954072, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 46, 32, 954072, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 46, 32, 954072, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '85402c33-2712-43ff-ba01-b4c2bd5f2100',
#                                       'request_id_created': '0HN49TF02OGJM:0000002C',
#                                       'request_id_modified': '0HN49TF02OGJM:0000002C',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}},
#             'INS_REQ_2': {'asset_class': 'Equities',
#                           'dom_ccy': 'GBP',
#                           'href': 'https://fbn-joe.lusid.com/api/api/instruments/LusidInstrumentId/LUID_00003D9M?scope=Demo2',
#                           'identifiers': {'ClientInternal': 'US0378331005',
#                                           'Isin': 'US0378331005',
#                                           'LusidInstrumentId': 'LUID_00003D9M'},
#                           'instrument_definition': {'dom_ccy': 'GBP',
#                                                     'identifiers': {'bbgid': None,
#                                                                     'client_internal': None,
#                                                                     'cusip': None,
#                                                                     'figi': None,
#                                                                     'ice_code': None,
#                                                                     'isin': None,
#                                                                     'lusid_instrument_id': None,
#                                                                     'quote_perm_id': None,
#                                                                     'red_code': None,
#                                                                     'ric': None,
#                                                                     'sedol': None},
#                                                     'instrument_type': 'Equity',
#                                                     'lot_size': 1},
#                           'links': None,
#                           'lookthrough_portfolio': None,
#                           'lusid_instrument_id': 'LUID_00003D9M',
#                           'name': 'Apple',
#                           'properties': [],
#                           'relationships': [],
#                           'scope': 'Demo2',
#                           'state': 'Active',
#                           'version': {'as_at_created': datetime.datetime(2024, 6, 11, 13, 46, 32, 954072, tzinfo=tzutc()),
#                                       'as_at_date': datetime.datetime(2024, 6, 11, 13, 46, 32, 954072, tzinfo=tzutc()),
#                                       'as_at_modified': datetime.datetime(2024, 6, 11, 13, 46, 32, 954072, tzinfo=tzutc()),
#                                       'as_at_version_number': 1,
#                                       'effective_from': datetime.datetime(1, 1, 1, 0, 0, tzinfo=tzutc()),
#                                       'entity_unique_id': '431952b2-1d64-4cce-a021-80b7e7efeee7',
#                                       'request_id_created': '0HN49TF02OGJM:0000002C',
#                                       'request_id_modified': '0HN49TF02OGJM:0000002C',
#                                       'staged_modification_id_modified': None,
#                                       'user_id_created': '00uv7uac52NTBxe1e2p7',
#                                       'user_id_modified': '00uv7uac52NTBxe1e2p7'}}}}

# %%
# Set up LUSID
import os
import pandas as pd
import json
import uuid
import pytz
from IPython.core.display import HTML
from datetime import datetime, timedelta, timezone
import pprint as pp

import logging
logging.basicConfig(level=logging.INFO)

# Import LUSID SDK
import lusid
import lusid.models as models

from lusid.utilities import ApiClientFactory
from lusidjam import RefreshingToken
from lusidtools.pandas_utils.lusid_pandas import lusid_response_to_data_frame
from lusidtools.jupyter_tools import StopExecution
from lusidtools.lpt.lpt import to_date
# Add constituents to ref portfolio.
def formatted_datetime(date_string):
    formatted_date = datetime.strptime(date_string, '%d-%b-%y')
    formatted_date = formatted_date.replace(tzinfo=timezone.utc)

    return formatted_date.isoformat()


ref_portfolio_constituents = pd.read_csv('sp500constituents.csv')

reference_portfolio_constituents = []

for index, constituent in ref_portfolio_constituents.iterrows():
    reference_portfolio_constituents.append(
        models.ReferencePortfolioConstituentRequest(
            instrument_identifiers = {
                'Instrument/default/Isin': constituent["ticker"]
            },
            weight = constituent["Weighting"],
            currency=constituent["currency"]
        )
    )

upsert_reference_portfolio_constituents_response = reference_portfolio_api.upsert_reference_portfolio_constituents(
    scope = scope,
    code = reference_portfolio_code,
    upsert_reference_portfolio_constituents_request = models.UpsertReferencePortfolioConstituentsRequest(
        effective_from = formatted_datetime('05-Jun-24'),
        weight_type='Static',
        constituents=reference_portfolio_constituents
    )
)

print(upsert_reference_portfolio_constituents_response)
# Out:
# {'href': None,
#  'links': [{'description': None,
#             'href': 'https://fbn-joe.lusid.com/api/api/schemas/entities/ReferencePortfolioConstituentRequest',
#             'method': 'GET',
#             'relation': 'EntitySchema'},
#            {'description': 'A link to the LUSID Insights website showing all '
#                            'logs related to this request',
#             'href': 'https://fbn-joe.lusid.com/app/insights/logs/0HN49EJ19VIIM:000001B7',
#             'method': 'GET',
#             'relation': 'RequestLogs'}],
#  'version': None}

# %%
# Setup notifications.
import lusid_notifications
import lusid_notifications.models as models
from lusidjam import RefreshingToken
from fbnsdkutilities import ApiClientFactory

notifications_api_factory = ApiClientFactory(
    lusid_notifications,
    token=RefreshingToken(),
    api_secrets_filename=secrets_path,
    app_name="VSCode",
)

print('LUSID Environment Initialised')

email_notifcation_api = notifications_api_factory.build(lusid_notifications.SubscriptionsApi)

subscription_code = "ConstituentChange"
subscription_display_name = 'Constituent Change'
subscription_description = 'Consituent change subscription'

"""
create_subscription = {
    "id": {
        "scope": f"{scope}", "code": f"{subscription_code}"
        },
    "displayName": f'{subscription_display_name}',
    "description": f'{subscription_description}',
    "status": "Active",
    "matchingPattern": {
        "eventType": "Manual", "filter": "Message eq 'TestMessage'"
        },
    "useAsAuth": "Auth user",
}
"""

api_response = email_notifcation_api.create_subscription(
    models.CreateSubscription(
        id = models.ResourceId(
            scope = scope,
            code = subscription_code
        ),
        display_name = subscription_display_name,
        description = subscription_description,
        status = 'Active',
        matching_pattern = models.MatchingPattern(
            event_type = "ConstituentsUpdated"
        )
    )
)
pp.pprint(api_response)
# Out:
# LUSID Environment Initialised
# {'created_at': datetime.datetime(2024, 6, 11, 13, 47, 25, 813139, tzinfo=tzutc()),
#  'created_by': '00uv7uac52NTBxe1e2p7',
#  'description': 'Consituent change subscription',
#  'display_name': 'Constituent Change',
#  'id': {'code': 'ConstituentChange', 'scope': 'Demo2'},
#  'last_modified_at': datetime.datetime(2024, 6, 11, 13, 47, 25, 813139, tzinfo=tzutc()),
#  'last_modified_by': '00uv7uac52NTBxe1e2p7',
#  'matching_pattern': {'event_type': 'ConstituentsUpdated', 'filter': None},
#  'notifications': None,
#  'status': 'Active',
#  'use_as_auth': '00uv7uac52NTBxe1e2p7'}

# %%
# Create notification.

notification_api = notifications_api_factory.build(lusid_notifications.NotificationsApi)

api_response = notification_api.create_email_notification(
    scope=scope,
    code=subscription_code,
    create_email_notification=models.CreateEmailNotification(
        description='Notification for when constituents change in ref portfolio.',
        subject='Constituents changed',
        plain_text_body='Constituents of the ref portfolio has changed.',
        email_address_to=['joe.cockings@finbourne.com']
    )
)


# Test change
